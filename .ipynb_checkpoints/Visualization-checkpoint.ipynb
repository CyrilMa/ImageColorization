# %%
import os, sys
import numpy as np

import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow
from skimage import io, color
from skimage.transform import *
import seaborn as sns
sns.set()

import keras

from config import dataset_conf
from nn import ImageColorizer
from data import DataGenerator, build_dataset, load_dataset

# %%
dataset = "SUN2012"
weights = "weight-13-0.01.hdf5"
colorizer = ImageColorizer(dataset_name = dataset)
colorizer.load_weights("weights/"+weights)
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# Input (InputLayer)              (None, 224, 224, 1)  0
# __________________________________________________________________________________________________
# global_features_extractor (Mode [(None, 256), (None, 38195072    Input[0][0]
# __________________________________________________________________________________________________
# dense_cl_1 (Dense)              (None, 256)          131328      global_features_extractor[1][1]
# __________________________________________________________________________________________________
# mid_features_extractor (Model)  multiple             3542784     global_features_extractor[1][2]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 256)          0           dense_cl_1[0][0]
# __________________________________________________________________________________________________
# fuse_and_colorize_model (Model) (None, None, None, 2 720874      global_features_extractor[1][0]
#                                                                  mid_features_extractor[1][0]
# __________________________________________________________________________________________________
# classification_output (Dense)   (None, 52)           13364       dropout_1[0][0]
# ==================================================================================================
# Total params: 42,603,422
# Trainable params: 42,540,762
# Non-trainable params: 62,660
# __________________________________________________________________________________________________
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# img_to_colorize (InputLayer)    (None, None, None, 1 0
# __________________________________________________________________________________________________
# img_with_style (InputLayer)     (None, 224, 224, 1)  0
# __________________________________________________________________________________________________
# shared_feature_extractor (Model multiple             2292864     img_to_colorize[0][0]
# __________________________________________________________________________________________________
# global_features_extractor (Mode [(None, 256), (None, 38195072    img_with_style[0][0]
# __________________________________________________________________________________________________
# mid_features_extractor (Model)  multiple             3542784     shared_feature_extractor[2][0]
# __________________________________________________________________________________________________
# fuse_and_colorize_model (Model) (None, None, None, 2 720874      global_features_extractor[2][0]
#                                                                  mid_features_extractor[2][0]
# ==================================================================================================
# Total params: 42,458,730
# Trainable params: 42,396,070
# Non-trainable params: 62,660
# __________________________________________________________________________________________________

# %%
train_set, val_set = load_dataset(dataset)

# %%
validation_generator = DataGenerator(train_set)

# %%
batch_imgs, batch_labels = validation_generator.__getitem__(2)

predicted, pred_labels = colorizer.nn.predict(batch_imgs)
lab_image = np.concatenate([batch_imgs*100,predicted*255-128], axis=3)
lab_image_true = np.concatenate([batch_imgs*100,batch_labels[0]*255-128], axis=3)
# Out:
# C:\Users\Cyril\Anaconda3\lib\site-packages\skimage\transform\_warps.py:24: UserWarning: The default multichannel argument (None) is deprecated.  Please specify either True or False explicitly.  multichannel will default to False starting with release 0.16.
#   warn('The default multichannel argument (None) is deprecated.  Please '
# C:\Users\Cyril\Anaconda3\lib\site-packages\skimage\transform\_warps.py:105: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# C:\Users\Cyril\Anaconda3\lib\site-packages\skimage\transform\_warps.py:110: UserWarning: Anti-aliasing will be enabled by default in skimage 0.15 to avoid aliasing artifacts when down-sampling images.
#   warn("Anti-aliasing will be enabled by default in skimage 0.15 to "
# C:\Users\Cyril\Anaconda3\lib\site-packages\skimage\transform\_warps.py:24: UserWarning: The default multichannel argument (None) is deprecated.  Please specify either True or False explicitly.  multichannel will default to False starting with release 0.16.
#   warn('The default multichannel argument (None) is deprecated.  Please '
# C:\Users\Cyril\Anaconda3\lib\site-packages\skimage\transform\_warps.py:105: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# C:\Users\Cyril\Anaconda3\lib\site-packages\skimage\transform\_warps.py:110: UserWarning: Anti-aliasing will be enabled by default in skimage 0.15 to avoid aliasing artifacts when down-sampling images.
#   warn("Anti-aliasing will be enabled by default in skimage 0.15 to "
# C:\Users\Cyril\Anaconda3\lib\site-packages\skimage\transform\_warps.py:24: UserWarning: The default multichannel argument (None) is deprecated.  Please specify either True or False explicitly.  multichannel will default to False starting with release 0.16.
#   warn('The default multichannel argument (None) is deprecated.  Please '
# C:\Users\Cyril\Anaconda3\lib\site-packages\skimage\transform\_warps.py:105: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# C:\Users\Cyril\Anaconda3\lib\site-packages\skimage\transform\_warps.py:110: UserWarning: Anti-aliasing will be enabled by default in skimage 0.15 to avoid aliasing artifacts when down-sampling images.
#   warn("Anti-aliasing will be enabled by default in skimage 0.15 to "
# C:\Users\Cyril\Anaconda3\lib\site-packages\skimage\transform\_warps.py:24: UserWarning: The default multichannel argument (None) is deprecated.  Please specify either True or False explicitly.  multichannel will default to False starting with release 0.16.
#   warn('The default multichannel argument (None) is deprecated.  Please '
# C:\Users\Cyril\Anaconda3\lib\site-packages\skimage\transform\_warps.py:105: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# C:\Users\Cyril\Anaconda3\lib\site-packages\skimage\transform\_warps.py:110: UserWarning: Anti-aliasing will be enabled by default in skimage 0.15 to avoid aliasing artifacts when down-sampling images.
#   warn("Anti-aliasing will be enabled by default in skimage 0.15 to "

# %%
# i = random.randint(0,32)
for i in range(32):
    plt.figure(figsize=(20,20))
    plt.subplot(131)
    imshow(batch_imgs[i,:,:,0], cmap='gray')
    plt.grid(False)
    plt.subplot(132)
    imshow(color.lab2rgb(lab_image[i]))
    plt.grid(False)
    plt.subplot(133)
    imshow(color.lab2rgb(lab_image_true[i]))
    plt.grid(False)
    # plt.subplot(133)
    # imshow(color.lab2rgb(ground_truth_lab_image[15]))
    # plt.grid(False)
    plt.show()
    print(i)
# Out:
# 23
# 30
# 18
# 18
# 18
